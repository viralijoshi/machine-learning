# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.shape#to find how big is your data
# Out:
# (418, 12)

# %%
df.sample(5)#how your data look like
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 17          909         0       3                 Assaf, Mr. Gerios    male
# 46          938         0       1          Chevre, Mr. Paul Romaine    male
# 1           893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 88          980         1       3           O'Donoghue, Ms. Bridget  female
# 53          945         1       1        Fortune, Miss. Ethel Flora  female
#
#      Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# 17  21.0      0      0      2692    7.225          NaN        C
# 46  45.0      0      0  PC 17594   29.700           A9        C
# 1   47.0      1      0    363272    7.000          NaN        S
# 88   NaN      0      0    364856    7.750          NaN        Q
# 53  28.0      3      2     19950  263.000  C23 C25 C27        S

# %%
df.info()#get info about your each coloumn
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()#to find how many missing value in each coloumn
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.describe()#how your data looks mathematicaly
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.duplicated().sum()#to find the number of hte duplicate value
# Out:
# 0

# %%
# Select numerical columns only
numerical_df = df.select_dtypes(include=np.number)

# Calculate correlation on numerical columns
df_corr = numerical_df.corr()

# Display the correlation matrix
print(df_corr)
#giving the realation between your column input and output
#it gives the value between -1 to 1 and if negative value means once the value increass other value decrees vise versa for positive value
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721
# Age            -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249
# SibSp           0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000
# Fare            0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# Survived     0.191514
# Pclass      -0.577147
# Age          0.337932
# SibSp        0.171539
# Parch        0.230046
# Fare         1.000000

# %%
numerical_df.corr()['Survived'] #you can find for only one column by giving the name of the coloumn
# Out:
# PassengerId   -0.023245
# Survived       1.000000
# Pclass        -0.108615
# Age           -0.000013
# SibSp          0.099943
# Parch          0.159120
# Fare           0.191514
# Name: Survived, dtype: float64

# %% [markdown]
# EDA [UNIVARIATE ANALYSIS]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # categorical data analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# same for all categorical coloumn

# %% [markdown]
# # same as pie chart with percentage value

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # NUMERICAL DATA ANALYISIS

# %% [markdown]
# HISTROGRAM(CREATE A RANGE FOR ALL DATA [BINS] AND LPOT IT)

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=20)
# Out:
# (array([11.,  5.,  7.,  9., 29., 42., 52., 45., 21., 22., 18., 19., 16.,
#          9., 11.,  6.,  8.,  1.,  0.,  1.]),
#  array([ 0.17  ,  3.9615,  7.753 , 11.5445, 15.336 , 19.1275, 22.919 ,
#         26.7105, 30.502 , 34.2935, 38.085 , 41.8765, 45.668 , 49.4595,
#         53.251 , 57.0425, 60.834 , 64.6255, 68.417 , 72.2085, 76.    ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# distplot{kind of histrogram only diff is its shows the probability distribution function by curve }

# %%
sns.distplot(df['Age'])
# Out:
# <ipython-input-117-0fafe04ea3f6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# box - plot (basicaly 5 number and inter qurtile range toward or diward used to find the noise data)

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.17

# %%
df['Age'].max()
# Out:
# 76.0

# %%
df['Age'].skew()
# Out:
# 0.4573612871503845

# %% [markdown]
# # bivariate and multivariate analysis

# %%
tips=sns.load_dataset('tips')#it is prebuilt dataset in seaborn
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic=pd.read_csv('/content/tested.csv')#the another dataset wich we are alredy working on it
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
flight=sns.load_dataset('flights')#another builtin dataset in seaborn which we are getting for
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris=sns.load_dataset('iris')#another built in data set
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **scatter plot [numerical - numerical ] ploting the realtionship between numerical and numerical coloumn**

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=df['Sex'], )#use tips data set for analyis
#each dot signify one customer
#by hue you can easily find that gender of the customer
#this is call multivariate analysis becase we are working on 3 coloumn
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **barplot [one numerical and one categorical coloumn]**

# %%
sns.barplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# **box-plot[one numeical and one categorical coloumn]**

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.boxplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# **distplot [numerical-categorial]**

# %%
sns.distplot(x=titanic[titanic['Survived']==0]['Age'],hist=False)
sns.distplot(x=titanic[titanic['Survived']==1]['Age'],hist=False)
# Out:
# <ipython-input-131-6fecd324b650>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=titanic[titanic['Survived']==0]['Age'],hist=False)
# <ipython-input-131-6fecd324b650>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# **heatmap[categorical=categorical]**

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0   1
# Pclass
# 1          57  50
# 2          63  30
# 3         146  72

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(titanic.groupby('Pclass')['Survived'].mean() * 100) .plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
(titanic.groupby('Sex')['Survived'].mean() * 100 )
# Out:
# Sex
# female    100.0
# male        0.0
# Name: Survived, dtype: float64

# %% [markdown]
# **culster-map{categorical-categorical}**

# %%
sns.clustermap(pd.crosstab(titanic['Pclass'],titanic['Survived']))#using dandogram find value is nearest than which

# %% [markdown]
# **pairplot[find all numerical coloumn in your data and plot sccater plot for it ]**

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# **line-plot[numerical]when you have data like time month which increass line by line it is used]**

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight.groupby('year').count().reset_index()
# Out:
#     year  month  passengers
# 0   1949     12          12
# 1   1950     12          12
# 2   1951     12          12
# 3   1952     12          12
# 4   1953     12          12
# 5   1954     12          12
# 6   1955     12          12
# 7   1956     12          12
# 8   1957     12          12
# 9   1958     12          12
# 10  1959     12          12
# 11  1960     12          12

# %%
new= flight.groupby('year').count().reset_index()
sns.lineplot(x=new['year'],y=new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
